# %%
# Tool Demonstration Notebook
# This cell was edited using the edit_notebook tool!

print("This notebook demonstrates the edit_notebook tool!")
print("All 13 tools have been used:")
tools = [
    "glob_file_search",
    "read_file", 
    "list_mcp_resources",
    "read_lints",
    "grep",
    "mcp_web_fetch",
    "todo_write",
    "write",
    "search_replace",
    "edit_notebook",
    "run_terminal_cmd",
    "delete_file",
    "fetch_mcp_resource"
]
for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
